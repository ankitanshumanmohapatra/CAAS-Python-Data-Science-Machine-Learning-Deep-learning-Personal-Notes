# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World!") #shift enter to run code
# Out:
# Hello World!

# %%
a= int(input())
b= int(input())
print(a+b)
# Out:
# 5
# 7
# 12

# %%
a= int(input())
b= int(input())
print(f"{a} + {b}= {a+b}" ) #f-string formatting
# printf( "%d + %d = %d", (x,y,z)) sting format of doing in c we can also use this in python but old version so better use above format
# Out:
# 4
# 5
# 4 + 5= 9

# %%
import matplotlib.pyplot as plt # library for plotting
plt.plot ([1,2,3,4,5] , [8,6,9,4,5], 'r--o') #x and y axis with red colour
plt.show()

# %% [markdown]
# I/O OPERATIONS
# IP->[Logic]->OUTPUT

# %%
name=input("Enter your name ")
# Out:
# Enter your name Ankit

# %%
import builtins
print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %%
import Ankit #here module does not exist so error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-44e1139634ac> in <module>
# ----> 1 import Ankit #here module does not exist so error
#
# ModuleNotFoundError: No module named 'Ankit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
ans= "5" + "6" #character addition
print(ans)
# Out:
# 56

# %%
ans= 4 + "5"  #type error as interger cannot be added to string so error
print(ans)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-96031225819a> in <module>
# ----> 1 ans= 4 + "5"
#       2 print(ans)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
ans= 4 + 5
print(ans)
# Out:
# 9

# %%
func=['abs', 'all', 'any','ascii', 'bin', 'bool', 'breakpoint', 'bytearray', 'bytes', 'callable', 'chr', 'classmethod', 'compile',
      'complex','copyright', 'credits', 'delattr', 'dict', 'dir', 'display', 'divmod', 'enumerate', 'eval', 'exec', 'execfile', 'filter',
      'float', 'format', 'frozenset', 'get_ipython', 'getattr', 'globals', 'hasattr', 'hash', 'help', 'hex', 'id', 'input', 'int', 
      'isinstance', 'issubclass', 'iter', 'len', 'license', 'list', 'locals', 'map', 'max', 'memoryview', 'min', 'next', 'object',
      'oct', 'open', 'ord', 'pow', 'print', 'property', 'range', 'repr', 'reversed', 'round', 'runfile', 'set', 'setattr', 'slice',
      'sorted', 'staticmethod', 'str', 'sum', 'super', 'tuple', 'type', 'vars', 'zip']

print(len(func)) #these many build in functions we are having in python
# Out:
# 75

# %% [markdown]
# I/O OPERATIONS
# Function here either
#     returns a value
#     or
#     returns None
# Application of this we will see below

# %%
ans=pow(2,3)
print(ans) #argument passes and returns a value
# Out:
# 8

# %%
x=print("Hello World")
print(x) #here print doesnot return a value so shows "None" So we cannot do this in Python
# Out:
# Hello World
# None

# %% [markdown]
# Working of print() function

# %%
print("Hello World!")

print(1234)   #Here no error but this is wrong as intergers cannot be passes directly in a function
# print -? 1234 -> int.__str__(1234) -> "1234" This is how print function operates in above line code explained below
#print then checks that interger type then calls a string function which gives string data

print("Okay" , "I can print" , 1,2,3,4)
# Out:
# Hello World!
# 1234
# Okay I can print 1 2 3 4

# %%
class A:
   def __str__(self): 
     #This method of double underscrole is called special method or magic method which are used to provide abstraction in py
         return 'ha ha ha ha do you get it?'      #str is a abstraction of print function
 
a = A() #a is object of class A

print(a)  # a ? A.__str__(a) checks object a of class A or not then calls string and prints
# Out:
# ha ha ha ha do you get it?

# %%
print("Hello", "World")  #Here in print function we can print multiple values and joins more than one value by a space

print("Okay")  #Also in print we can automatically print word in next line
# Out:
# Hello World
# Okay

# %%
print(1, 2, 3, 4)
# in print(1space2space3space4space\n) We cannot pass multiple value to string in C Programming
# Out:
# 1 2 3 4

# %%
print(1,2,3,4, sep='\n')  #separation parameter sep=" "" and end parameter new line end=" "
# Out:
# 1
# 2
# 3
# 4

# %%
print("Hello", end=" ") #just uses space and does not get newline => end with space 

print("World!")
# Out:
# Hello World!

# %% [markdown]
# Till now we read dir ,builtins ,**return** value & print functions

# %% [markdown]
#    #    \ -> special symbol -> escape
#
#  #skipping after what ever in print
#
#           "n" -> n
#
#           "\n" -> new line #escape to new line or skip to new line

# %%
s= "\\" #We are skipping backslash then slash \
print(s)
# Out:
# \

# %%
s="\""
print(s)
# Out:
# "

# %%
s= "\u20B9"
print(s)
# Out:
# ₹

# %% [markdown]
# \n for new line
#
# 1.   \n for new line
# 2.   \t for new tab space/ indent
# 3.   for enclosed double quote in a string we use \ "
# 4.   for enclosed ' in string \ '
# 5.   for enlosed \ in string \ \ Shown below it's use

# %%
s= "he said, "She is beautiful.""  #Shows error as python reads both double quote to be same so we use backclash double quote as shown below
print(s)
# Out:
#   File "<ipython-input-2-82fa9ef64c28>", line 1
#     s= "he said, "She is beautiful.""
#                   ^
# SyntaxError: invalid syntax

# %%
s= "he said, \"She is beautiful.\""  #to prevent previous mistake we use backslash double quote
print(s)
# Out:
# he said, "She is beautiful."

# %%
print(1,2,3,4, sep='\\')
# Out:
# 1\2\3\4

# %% [markdown]
# 1.   Encoding
# 2. **UnicodeCode or byte mapped in dictionary then converts to character (Often ascii characters or utf-8 character sets) ****
# 3. Examples given below

# %%
print("\u20B9") #Encoding
# Out:
# ₹

# %%
print("\u0061")  #Exaples of Encoding
print("\u0063")
# Out:
# a
# c

# %%
print("\u00CD") #unicode value the inside 4 digits
# Out:
# Í

# %%
print("\uFEEF")
# Out:
# ﻯ

# %% [markdown]
# # PYTHON STRING FORMATTING
#
#
#
# 1.   As we did earlier f string formatting similar to that
# 2.   Use ful for print function inside any values we will be calling

# %%
name = input("enter your name: ")
age = int(input("enter your age: "))

message = f"Hello, you are years old."   #Name and age are ot called here so we use below fomat for doing that
# f-string
print(message)
# Out:
# enter your name: Ankit
# enter your age: 20
# Hello, you are years old.

# %%
name = input("enter your name: ")
age = int(input("enter your age: "))

message = f"Hello {name}, you are {age} years old."  #replacing by using curly bracket {} by name data and age variable data CURLY BRACKETS ARE PLACE HOLDERS INSODE PRINT
# f-string
print(message)
# Out:
# enter your name: Ankit
# enter your age: 20
# Hello Ankit, you are 20 years old.

# %%
x = 10
y = 20
r = x + y
# string formatting
print("%d + %d = %d"%(x, y, r))  #Use in c programming OLD SCHOOL can be used in python old
# old school method
print("{} + {} = {}".format(x, y, r))   #curly brackets means place holders and somevalue will be replaced there
# f-string python >= 3.6
print(f"{x} + {y} = {r}")  #New for python 3.6+ better good easy
# Out:
# 10 + 20 = 30
# 10 + 20 = 30
# 10 + 20 = 30

# %% [markdown]
# ###***EVERYTHING is object in Python!***
#
#
#
# Variable and Object difference
#
#
# 1.   OBJECT IS COLLECTION OF ATTRIBUTES WHICH CAN DEFINE A REAL TIME ENTITY
# 2.   OBJECT IS ALSO KNOWN AS DATA MEMEBERS
#
#
#
# 1.   Object as an array or structure
# 2.   reference to an instance
#
# x=10  #x is reference of an interger instance
# print(f"x= {x}")

# %%
x=10  #x is reference of an interger instance  ***IMPORTANT***
print(f"x= {x}")
# Out:
# x= 10

# %%
int x,y,z;
 
 x= 4.5;   #here we cannot assign values i.2 float to a already defined integer type

# %%
a=[1,2,3,4]  #can be object to a class

# %%
class  #we cannot think without a object
      #Class is a collection of data members (objects) and member function (behaviour of an object)  ***IMPORTANT**
      #group of similar objects
   ?
  object    #object is an array we can fetch it
            #object is a collection of atttributes whichh can define a real time entity ***IMPORTANT***
            #also knows as data members                                                 ***IMPORTANT***
   ?

# %% [markdown]
# ###**CLASS**  - we cannot think without a object
# ###Class is a collection of data members (objects) and member function (behaviour of an object)
# ###It is a group of similar objects
#
#
# ###**OBJECT**
# ###object is an array we can fetch it
# ###object is a collection of atttributes whichh can define a real time entity
# ###It is also knows as data members
#
#
# ###If we need to store data we need object
# ###to process data we need methods, which is collected in a class
#
#
# ###***CLASS***
# collection of methods(functions)
# ###***Object***
# collection of attributes
#
# ###Class are used to create secondary data types
#
#
# ###***DATA TYPES***
# It tells us how data is going to be stored and processed inside a computer memory
#
#
# 1.   Representation in memory / structure of data
# ###how information is going to be stored in computer memory
# 2.   Operation on data:-
# ###access,  update, delete, insert, sort, replace
#
# ###To access data from array- O(1)
# ###To access data from linked list- O(n)
# random access [10,50,60,70,30,80]

# %%
arr=[1, 2, 3, 4]

# "1  2  3  4  store data anywhere in memory

# %% [markdown]
# ###EVERY DATA TYPE IN PYTHON IS AN INSTANCE OF DATA CLASS

# %%
x=10
#x is a reference to an interger object

# %% [markdown]
# ###Built in DATA TYPES IN PYTHON
#
# CLASSES-
#
# 1. Numbers-  int, float, complex
# 2. String-  single or multiline strings
# 3. List-  collection of items- homogenous or heterogenous
# 4. Tuple- immutable list(update operation we cannot change here in tuples)
# 5. Dictionaries- map-type, collection of key-value pairs
# 6. Set- map-type, collection of unique immutable values
# 7. Frozen sets- immutable sets
# 8. None type- used to nothing/ null values or values that does not exist
# 9. Bollean types- True , False

# %% [markdown]
# ####***NUMBERS***

# %%
Class int:
  magic methods/ dunders methods/ operators/ short hand notation

# %% [markdown]
# ###everything is object in python!
# either interger or any other object
# ###1.**magic methods/ dunders methods/ operators/ short hand notation**
#
# 2.**Regular methods**

# %%
x= 4+5
print(x)

x= int.__add__(4,5)   #magic methods or in c called Operator overloading
print(x)
# Out:
# 9
# 9

# %%
print(5)
#here directly python will not print interger 5 but will call the str function as shown below
print(int.__str__(5)) #happens inside python magic method
# Out:
# 5
# 5

# %%
x= "4" + "5"    #MAGIC METHODS in Python or in other language called Operator overloading
print(x)

x= str.__add__("4","5")  #magic methods/operators
print(x)
# Out:
# 45
# 45

# %%
#similarly in length method here algo magic method used inside of len()
s=len("Ankit")
print(s)

n=str.__len__("Ankit")  #above process inside happens this str operation or Magic method
print(n)
# Out:
# 5
# 5

# %%
ls= len([1,2,3])
print(ls)

n=list.__len__([1,2,3])  #magic operator of above code
print(n)
# Out:
# 3
# 3

# %% [markdown]
# ###**Abover also as we saw inside every print function str or len or any Magic operation is performed happening behind the scene in OOPS
# ###**some more examples are below in a class we perform some operations**

# %%
class My:  #class we are defining as my function
  def __str__(self):   #magic operaton on string 
    return "I am God"
    def __add__(self, other):   #another magic operation
      return "shock laga!"

# %%
a = my() #1st object we are creating of this my class
b = my() #2nd object we are creating of this my class

# %%
a + b
# Out:
# 'shock laga!'

# %%
print(a) #a is instance of my class and it calls .__str__(a) and passing object a
print(b)
# Out:
# I am god
# I am god

# %%
a=5
print(a+10) #canned do this
# Out:
# 15

# %% [markdown]
# ###**all constructors are known as magic method/dunders methods**

# %% [markdown]
# ###magic methods any methods that donot hold driectly are known as Magic methods

# %% [markdown]
# We can invoke magic methods by various operators and short hand notations or built in functions

# %%
5+6
# Out:
# 11

# %%
int.__add__(5,6)  #magic methods here used internally in the 5+6 addition
# Out:
# 11

# %% [markdown]
# ###**Now regular Mthods (Class types)**

# %%
a = 5
# a is refrence/identifier to int instance (object)

# %%
print(type(a))   #to get type of a int
# Out:
# <class 'int'>

# %%
# methods ? to get all magic methods-underscrolls all
print(dir(a))  #below are magic methods
# Out:
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']

# %% [markdown]
# ###out of the above methods below are regular methods
# ### 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real'

# %% [markdown]
# ###**.DOT METHOD**

# %%
a=10
a.__add__(5)   #  . dot is used to access method using object here a is object and we are accessing it and as a is interger
# Out:
# 15

# %% [markdown]
# Some methods use

# %%
#unsigned interger  -> 2byte ->16->?
a=121            
value=a.bit_length()    #binary value to decimal value
print(f"binary value of {a} is {a:b}")
print(value)
# Out:
# binary value of 121 is 1111001
# 7

# %%
s="hello world"
print(type(s))      #gives string class and below are methods we can use to get this string class
# Out:
# <class 'str'>

# %%
print(dir(s))  #below are the methods we can use to get this string class
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# ###***help function in python to get how a function works***  IMPORTANT

# %%
help(s.lower)  #lower function use given here sysntax help(object.function)
# Out:
# Help on built-in function lower:
#
# lower() method of builtins.str instance
#     Return a copy of the string converted to lowercase.

# %%
#use of lower below
s="HeLLO WorlD"  #lower() function use----upper case to lower

ns=s.lower()

print(s)
print(ns)
# Out:
# HeLLO WorlD
# hello world

# %%
x=10
s=f"x={x}"    #f string fomating
print(s)
# Out:
# x=10

# %%
x=10
s=f"x={x:b}"    #f string fomatingafter colon b we get binary value of x
print(s)
# Out:
# x=1010

# %% [markdown]
#     hexadecimal  x
#
#     binary       b
#
#     octal        o
#
#     float        f
#
#   ###***use instead of b in fomatting***

# %% [markdown]
# ###***abstraction is way by which we can background details by showing only essential information***
# limited information ex. print is also an abstraction of write function

# %%
print("Hello World!")  #also a abstraction (limited details only essentially it prints)
#full operation of print done below
# Out:
# Hello World!

# %%
#print operation full background details write operation during abstraction
import sys

sys.stdout.write("Hello World!\n")
# Out:
# Hello World!
